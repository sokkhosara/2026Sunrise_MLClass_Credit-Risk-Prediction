# %%
import requests

url = 'http://localhost:9696/predict'

customer_id = 'xyz-123'
customer = {
    "age": "",
    "sex": "female",
    "job": 3,
    "housing": "free",
    "saving_accounts": "little",
    "checking_account": "moderate",
    "credit_amount": 600,
    "duration": 120,
    "purpose": "business"
}

# Send POST request
response = requests.post(url, json=customer).json()
print(response)
# Out:
# {'risk_flag': 0, 'risk_probability': 0.02908315975048787}
